# %%
import zipfile
import os

# %%
# Define the paths
zip_path = os.path.expanduser('../data/raw/AllPublicXML.zip')
extract_path = os.path.expanduser('../data/trials')

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
